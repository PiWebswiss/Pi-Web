# %%
import os

# %%
os.listdir()
# Out:
# ['agnatha.jpg',
#  'ammonoid.jpg',
#  'amphibian.jpg',
#  'angiosperm.jpg',
#  'avialae.jpg',
#  'belemnite.jpg',
#  'bivalve.jpg',
#  'blastoid.jpg',
#  'bone fragment.jpg',
#  'brachiopod.jpg',
#  'bryozoan.jpg',
#  'chelicerate.jpg',
#  'chondrichthyes.jpg',
#  'conodont.jpg',
#  'crinoid.jpg',
#  'crocodylomorph.jpg',
#  'crustacean.jpg',
#  'echinoid.jpg',
#  'gastropod.jpg',
#  'graptolite.jpg',
#  'gymnosperm.jpg',
#  'image coral.jpg',
#  'image insect.jpg',
#  'mammal teeth.jpg',
#  'mammal.jpg',
#  'marine reptile.jpg',
#  'myriapod.jpg',
#  'nautiloid.jpg',
#  'ophiuroid.jpg',
#  'ornithischian.jpg',
#  'osteichthyes.jpg',
#  'petrified wood.jpg',
#  'placoderms.jpg',
#  'pteridophyte.jpg',
#  'pterosaurs.jpg',
#  'reptile teeth.jpg',
#  'sauropodomorph.jpg',
#  'script.ipynb',
#  'shark teeth.jpg',
#  'snake.jpg',
#  'sponge.jpg',
#  'starfish.jpg',
#  'stromatolite.jpg',
#  'theropod.jpg',
#  'trace fossil.jpg',
#  'trilobite.jpg',
#  'turtle.jpg']

# %%
# Mapping from the initial dictionary
initial_mapping = {
    'agnatha': 0,
    'ammonoid': 1,
    'amphibian': 2,
    'angiosperm': 3,
    'avialae': 4,
    'belemnite': 5,
    'bivalve': 6,
    'blastoid': 7,
    'bone_fragment': 8,
    'brachiopod': 9,
    'bryozoan': 10,
    'chelicerate': 11,
    'chondrichthyes': 12,
    'conodont': 13,
    'coral': 14,
    'crinoid': 15,
    'crocodylomorph': 16,
    'crustacean': 17,
    'echinoid': 18,
    'gastropod': 19,
    'graptolite': 20,
    'gymnosperm': 21,
    'insect': 22,
    'mammal': 23,
    'mammal_teeth': 24,
    'marine_reptile': 25,
    'myriapod': 26,
    'nautiloid': 27,
    'ophiuroid': 28,
    'ornithischian': 29,
    'osteichthyes': 30,
    'petrified_wood': 31,
    'placoderms': 32,
    'pteridophyte': 33,
    'pterosaurs': 34,
    'reptile_teeth': 35,
    'sauropodomorph': 36,
    'shark_teeth': 37,
    'snake': 38,
    'sponge': 39,
    'starfish': 40,
    'stromatolite': 41,
    'theropod': 42,
    'trace_fossil': 43,
    'trilobite': 44,
    'turtle': 45
}


image_names = [
    'agnatha.jpg',
 'ammonoid.jpg',
 'amphibian.jpg',
 'angiosperm.jpg',
 'avialae.jpg',
 'belemnite.jpg',
 'bivalve.jpg',
 'blastoid.jpg',
 'bone fragment.jpg',
 'brachiopod.jpg',
 'bryozoan.jpg',
 'chelicerate.jpg',
 'chondrichthyes.jpg',
 'conodont.jpg',
 'crinoid.jpg',
 'crocodylomorph.jpg',
 'crustacean.jpg',
 'echinoid.jpg',
 'gastropod.jpg',
 'graptolite.jpg',
 'gymnosperm.jpg',
 'image coral.jpg',
 'image insect.jpg',
 'mammal teeth.jpg',
 'mammal.jpg',
 'marine reptile.jpg',
 'myriapod.jpg',
 'nautiloid.jpg',
 'ophiuroid.jpg',
 'ornithischian.jpg',
 'osteichthyes.jpg',
 'petrified wood.jpg',
 'placoderms.jpg',
 'pteridophyte.jpg',
 'pterosaurs.jpg',
 'reptile teeth.jpg',
 'sauropodomorph.jpg',
 'shark teeth.jpg',
 'snake.jpg',
 'sponge.jpg',
 'starfish.jpg',
 'stromatolite.jpg',
 'theropod.jpg',
 'trace fossil.jpg',
 'trilobite.jpg',
 'turtle.jpg']

# Correcting the mapping to use image names instead of numbers
corrected_mapping = {key: image_names[value] for key, value in initial_mapping.items()}

corrected_mapping
# Out:
# {'agnatha': 'agnatha.jpg',
#  'ammonoid': 'ammonoid.jpg',
#  'amphibian': 'amphibian.jpg',
#  'angiosperm': 'angiosperm.jpg',
#  'avialae': 'avialae.jpg',
#  'belemnite': 'belemnite.jpg',
#  'bivalve': 'bivalve.jpg',
#  'blastoid': 'blastoid.jpg',
#  'bone_fragment': 'bone fragment.jpg',
#  'brachiopod': 'brachiopod.jpg',
#  'bryozoan': 'bryozoan.jpg',
#  'chelicerate': 'chelicerate.jpg',
#  'chondrichthyes': 'chondrichthyes.jpg',
#  'conodont': 'conodont.jpg',
#  'coral': 'crinoid.jpg',
#  'crinoid': 'crocodylomorph.jpg',
#  'crocodylomorph': 'crustacean.jpg',
#  'crustacean': 'echinoid.jpg',
#  'echinoid': 'gastropod.jpg',
#  'gastropod': 'graptolite.jpg',
#  'graptolite': 'gymnosperm.jpg',
#  'gymnosperm': 'image coral.jpg',
#  'insect': 'image insect.jpg',
#  'mammal': 'mammal teeth.jpg',
#  'mammal_teeth': 'mammal.jpg',
#  'marine_reptile': 'marine reptile.jpg',
#  'myriapod': 'myriapod.jpg',
#  'nautiloid': 'nautiloid.jpg',
#  'ophiuroid': 'ophiuroid.jpg',
# ...
